# %%
from DataSynthesizer.DataDescriber import DataDescriber
from DataSynthesizer.DataGenerator import DataGenerator
from DataSynthesizer.ModelInspector import ModelInspector
from DataSynthesizer.lib.utils import read_json_file, display_bayesian_network

import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# input dataset
input_data = 'Sandwich/J334772Truncated2.csv'
# location of two output files
mode = 'correlated_attribute_mode'
description_file = 'description.json'
synthetic_data = 'synthetic_data.csv'

# %%
# An attribute is categorical if its domain size is less than this threshold.
threshold_value = 20

# specify categorical attributes
categorical_attributes = {'RT13V7': True, 'RT13V8': True} #{'RT13V3': True, 'RT13V4',RT13V11, RT13V12 RT13V13, RT13V14, RT13V15, RT13V18, RT13V21, RT13V24, RT13V27, RT13V28, RT13V29, RT13V30, RT13V31, RT13V32 RT13V33}

# specify which attributes are candidate keys of input dataset.
candidate_keys = {'RT13V2': True}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.
epsilon = 1

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 2

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = 9063

null_values = [99999, 999999999]

# %%
#Runs one iteration of creating the Bayesian network, generating the data and comparing it to the original data
def runDataSynth(degree, epsilon, gennum, threshold_value, null_values, description_file, synthetic_data):
    print("Data generated for epsilon " + str(epsilon) + " and degree " + str(degree))
    #Generates the Bayesian Network
    describer = DataDescriber(category_threshold=threshold_value,  null_values=null_values)
    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys)
    describer.save_dataset_description_to_file(description_file)

    #Displays the bayesian network
    print("Bayesian for epsilon " + str(epsilon) + " and degree " + str(degree))
    display_bayesian_network(describer.bayesian_network)
    #generates the synthetic data and saves it to synthetic data
    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    generator.save_synthetic_data(synthetic_data)

    # Read both datasets using Pandas.
    input_df = pd.read_csv(input_data, skipinitialspace=True)
    synthetic_df = pd.read_csv(synthetic_data)
    # Read attribute description from the dataset description file.
    attribute_description = read_json_file(description_file)['attribute_description']
    inspector = ModelInspector(input_df, synthetic_df, attribute_description)
    

    print("Comparison for epsilon " + str(epsilon) + " and degree " + str(degree))
    
    path = 'datasynthplt/' + "epsilon" + str(epsilon) + "degree" + str(degree)
    isExist = os.path.exists(path)
    if not isExist:
        os.makedirs(path)
    for attribute in synthetic_df.columns:
        photo = path + "/" + str(attribute) +'.png'
        inspector.compare_histograms(attribute)
        plt.savefig(photo, dpi=300, bbox_inches='tight')
        plt.cla()
        plt.close()

    inspector.mutual_information_heatmap()
    photo = path + '/heatmap.png'
    plt.savefig(photo, dpi=300, bbox_inches='tight')
    plt.cla()
    plt.close()
    
    return describer

# %%
runDataSynth(1, epsilon, num_tuples_to_generate
, threshold_value, null_values, description_file, synthetic_data)
# Out:
# Data generated for epsilon 1 and degree 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V42
# Adding attribute RT13V36
# Adding attribute RT13V21
# Adding attribute RT13V40
# Adding attribute RT13V19
# Adding attribute RT13V51
# Adding attribute RT13V49
# Adding attribute RT13V14
# Adding attribute RT13V34
# Adding attribute RT13V16
# Adding attribute RT13V22
# Adding attribute RT13V48
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V32
# Adding attribute RT13V31
# Adding attribute RT13V30
# Adding attribute RT13V52
# Adding attribute RT13V27
# Adding attribute RT13V13
# Adding attribute RT13V29
# Adding attribute RT13V9
# Adding attribute RT13V24
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V18
# Adding attribute RT13V15
# Adding attribute RT13V11
# Adding attribute RT13V37
# Adding attribute RT13V12
# Adding attribute RT13V28
# Adding attribute RT13V7
# Adding attribute RT13V43
# Adding attribute RT13V25
# ========================== BN constructed ==========================
# Bayesian for epsilon 1 and degree 1
# Constructed Bayesian network:
#     RT13V39 has parents ['RT13V33'].
#     RT13V45 has parents ['RT13V39'].
#     RT13V42 has parents ['RT13V33'].
#     RT13V36 has parents ['RT13V33'].
#     RT13V21 has parents ['RT13V36'].
#     RT13V40 has parents ['RT13V33'].
#     RT13V19 has parents ['RT13V42'].
#     RT13V51 has parents ['RT13V39'].
#     RT13V49 has parents ['RT13V42'].
#     RT13V14 has parents ['RT13V42'].
#     RT13V34 has parents ['RT13V33'].
#     RT13V16 has parents ['RT13V14'].
#     RT13V22 has parents ['RT13V51'].
#     RT13V48 has parents ['RT13V42'].
#     RT13V4  has parents ['RT13V14'].
#     RT13V8  has parents ['RT13V4'].
#     RT13V3  has parents ['RT13V4'].
#     RT13V32 has parents ['RT13V4'].
#     RT13V31 has parents ['RT13V14'].
#     RT13V30 has parents ['RT13V31'].
#     RT13V52 has parents ['RT13V51'].
#     RT13V27 has parents ['RT13V4'].
#     RT13V13 has parents ['RT13V4'].
#     RT13V29 has parents ['RT13V33'].
#     RT13V9  has parents ['RT13V45'].
#     RT13V24 has parents ['RT13V9'].
#     RT13V10 has parents ['RT13V48'].
#     RT13V46 has parents ['RT13V49'].
#     RT13V18 has parents ['RT13V21'].
#     RT13V15 has parents ['RT13V36'].
#     RT13V11 has parents ['RT13V24'].
#     RT13V37 has parents ['RT13V4'].
#     RT13V12 has parents ['RT13V11'].
#     RT13V28 has parents ['RT13V51'].
#     RT13V7  has parents ['RT13V39'].
#     RT13V43 has parents ['RT13V51'].
#     RT13V25 has parents ['RT13V27'].
# Comparison for epsilon 1 and degree 1

# %%
#Run Datasynth on multiple different values of epsilon and degree of Bayesian Network equal to 0(This automatically generates the Bayesian Network)
epsilon_vals = [0.05, 0.1, 0.2, 0.4, 0.8, 1.6]
describers0 = []
for epsilon in epsilon_vals:
    describer0 = runDataSynth(0, epsilon, num_tuples_to_generate, threshold_value, null_values, description_file, synthetic_data)
    describers0.append(describer)
# Out:
# Data generated for epsilon 0.05 and degree 0
# Warning: k is not properly computed!
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V7
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V8
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.05 and degree 0
# Constructed Bayesian network:
#     RT13V29 has parents ['RT13V33'].
#     RT13V39 has parents ['RT13V29', 'RT13V33'].
#     RT13V31 has parents ['RT13V29', 'RT13V39', 'RT13V33'].
#     RT13V27 has parents ['RT13V39', 'RT13V31', 'RT13V33'].
#     RT13V19 has parents ['RT13V31', 'RT13V27', 'RT13V39'].
#     RT13V34 has parents ['RT13V31', 'RT13V19', 'RT13V29'].
#     RT13V21 has parents ['RT13V31', 'RT13V27', 'RT13V29'].
#     RT13V48 has parents ['RT13V27', 'RT13V19', 'RT13V39'].
#     RT13V51 has parents ['RT13V34', 'RT13V21', 'RT13V27'].
#     RT13V15 has parents ['RT13V19', 'RT13V48', 'RT13V39'].
#     RT13V42 has parents ['RT13V31', 'RT13V21', 'RT13V29'].
#     RT13V24 has parents ['RT13V19', 'RT13V15', 'RT13V31'].
#     RT13V28 has parents ['RT13V19', 'RT13V21', 'RT13V33'].
#     RT13V49 has parents ['RT13V21', 'RT13V51', 'RT13V33'].
#     RT13V4  has parents ['RT13V42', 'RT13V49', 'RT13V31'].
#     RT13V7  has parents ['RT13V28', 'RT13V4', 'RT13V51'].
#     RT13V3  has parents ['RT13V15', 'RT13V42', 'RT13V39'].
#     RT13V43 has parents ['RT13V42', 'RT13V28', 'RT13V27'].
#     RT13V37 has parents ['RT13V48', 'RT13V43', 'RT13V34'].
#     RT13V45 has parents ['RT13V34', 'RT13V43', 'RT13V19'].
#     RT13V52 has parents ['RT13V42', 'RT13V28', 'RT13V19'].
#     RT13V32 has parents ['RT13V15', 'RT13V4', 'RT13V48'].
#     RT13V14 has parents ['RT13V7', 'RT13V43', 'RT13V51'].
#     RT13V30 has parents ['RT13V7', 'RT13V52', 'RT13V24'].
#     RT13V9  has parents ['RT13V49', 'RT13V30', 'RT13V27'].
#     RT13V22 has parents ['RT13V14', 'RT13V30', 'RT13V34'].
#     RT13V10 has parents ['RT13V52', 'RT13V22', 'RT13V19'].
#     RT13V46 has parents ['RT13V49', 'RT13V4', 'RT13V27'].
#     RT13V16 has parents ['RT13V4', 'RT13V45', 'RT13V48'].
#     RT13V13 has parents ['RT13V48', 'RT13V30', 'RT13V31'].
#     RT13V11 has parents ['RT13V7', 'RT13V52', 'RT13V28'].
#     RT13V36 has parents ['RT13V7', 'RT13V30', 'RT13V48'].
#     RT13V18 has parents ['RT13V3', 'RT13V9', 'RT13V39'].
#     RT13V25 has parents ['RT13V3', 'RT13V11', 'RT13V39'].
#     RT13V8  has parents ['RT13V49', 'RT13V11', 'RT13V33'].
#     RT13V40 has parents ['RT13V45', 'RT13V30', 'RT13V39'].
#     RT13V12 has parents ['RT13V30', 'RT13V9', 'RT13V51'].
# Comparison for epsilon 0.05 and degree 0
# Data generated for epsilon 0.1 and degree 0
# Warning: k is not properly computed!
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 describers0 = []
#       4 for epsilon in epsilon_vals:
# ----> 5     describer0 = runDataSynth(0, epsilon, num_tuples_to_generate, threshold_value, null_values, description_file, synthetic_data)
#       6     describers0.append(describer)
#
# Cell In[4], line 6, in runDataSynth(degree, epsilon, gennum, threshold_value, null_values, description_file, synthetic_data)
#       4 #Generates the Bayesian Network
#       5 describer = DataDescriber(category_threshold=threshold_value,  null_values=null_values)
# ----> 6 describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data,
#       7                                                     epsilon=epsilon,
#       8                                                     k=degree,
#       9                                                     attribute_to_is_categorical=categorical_attributes,
#      10                                                     attribute_to_is_candidate_key=candidate_keys)
#      11 describer.save_dataset_description_to_file(description_file)
#      13 #Displays the bayesian network
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/site-packages/DataSynthesizer/DataDescriber.py:179, in DataDescriber.describe_dataset_in_correlated_attribute_mode(self, dataset_file, k, epsilon, attribute_to_datatype, attribute_to_is_categorical, attribute_to_is_candidate_key, categorical_attribute_domain_file, numerical_attribute_ranges, seed)
#     176 if self.df_encoded.shape[1] < 2:
#     177     raise Exception("Correlated Attribute Mode requires at least 2 attributes(i.e., columns) in dataset.")
# --> 179 self.bayesian_network = greedy_bayes(self.df_encoded, k, epsilon / 2, seed=seed)
#     180 self.data_description['bayesian_network'] = self.bayesian_network
#     181 self.data_description['conditional_probabilities'] = construct_noisy_conditional_distributions(
#     182     self.bayesian_network, self.df_encoded, epsilon / 2)
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/site-packages/DataSynthesizer/lib/PrivBayes.py:160, in greedy_bayes(dataset, k, epsilon, seed)
#     157 tasks = [(child, V, num_parents, split, dataset) for child, split in
#     158          product(rest_attributes, range(len(V) - num_parents + 1))]
#     159 with Pool() as pool:
# --> 160     res_list = pool.map(worker, tasks)
#     162 for res in res_list:
#     163     parents_pair_list += res[0]
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/anaconda3/envs/REURes/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
plt.close('all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.close('all')
# ----> 2 fig.clf()
#
# NameError: name 'fig' is not defined

# %%
#Run Datasynth on multiple different values of epsilon and degree of Bayesian Network equal to 2
epsilon_vals = [0.05, 0.1, 0.2, 0.4, 0.8, 1.6]
describers2 = []
for epsilon in epsilon_vals:
    describer2 = runDataSynth(2, epsilon, num_tuples_to_generate, threshold_value, null_values, description_file, synthetic_data)
    describers2.append(describer2)
# Out:
# Data generated for epsilon 0.05 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V7
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V8
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.05 and degree 2
# Constructed Bayesian network:
#     RT13V29 has parents ['RT13V33'].
#     RT13V39 has parents ['RT13V29', 'RT13V33'].
#     RT13V31 has parents ['RT13V39', 'RT13V33'].
#     RT13V27 has parents ['RT13V39', 'RT13V29'].
#     RT13V19 has parents ['RT13V27', 'RT13V31'].
#     RT13V34 has parents ['RT13V27', 'RT13V39'].
#     RT13V21 has parents ['RT13V31', 'RT13V39'].
#     RT13V48 has parents ['RT13V34', 'RT13V31'].
#     RT13V51 has parents ['RT13V21', 'RT13V34'].
#     RT13V15 has parents ['RT13V19', 'RT13V27'].
#     RT13V42 has parents ['RT13V31', 'RT13V39'].
#     RT13V24 has parents ['RT13V21', 'RT13V19'].
#     RT13V28 has parents ['RT13V39', 'RT13V29'].
#     RT13V49 has parents ['RT13V27', 'RT13V29'].
#     RT13V4  has parents ['RT13V24', 'RT13V19'].
#     RT13V7  has parents ['RT13V28', 'RT13V24'].
#     RT13V3  has parents ['RT13V19', 'RT13V27'].
#     RT13V43 has parents ['RT13V3', 'RT13V34'].
#     RT13V37 has parents ['RT13V42', 'RT13V51'].
#     RT13V45 has parents ['RT13V49', 'RT13V21'].
#     RT13V52 has parents ['RT13V45', 'RT13V21'].
#     RT13V32 has parents ['RT13V7', 'RT13V42'].
#     RT13V14 has parents ['RT13V32', 'RT13V28'].
#     RT13V30 has parents ['RT13V52', 'RT13V7'].
#     RT13V9  has parents ['RT13V15', 'RT13V21'].
#     RT13V22 has parents ['RT13V49', 'RT13V15'].
#     RT13V10 has parents ['RT13V32', 'RT13V48'].
#     RT13V46 has parents ['RT13V30', 'RT13V34'].
#     RT13V16 has parents ['RT13V3', 'RT13V24'].
#     RT13V13 has parents ['RT13V16', 'RT13V27'].
#     RT13V11 has parents ['RT13V45', 'RT13V43'].
#     RT13V36 has parents ['RT13V49', 'RT13V24'].
#     RT13V18 has parents ['RT13V49', 'RT13V27'].
#     RT13V25 has parents ['RT13V49', 'RT13V27'].
#     RT13V8  has parents ['RT13V25', 'RT13V33'].
#     RT13V40 has parents ['RT13V24', 'RT13V27'].
#     RT13V12 has parents ['RT13V11', 'RT13V28'].
# Comparison for epsilon 0.05 and degree 2
# Data generated for epsilon 0.1 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V7
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V8
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.1 and degree 2
# Constructed Bayesian network:
#     RT13V29 has parents ['RT13V33'].
#     RT13V39 has parents ['RT13V29', 'RT13V33'].
#     RT13V31 has parents ['RT13V39', 'RT13V33'].
#     RT13V27 has parents ['RT13V31', 'RT13V29'].
#     RT13V19 has parents ['RT13V27', 'RT13V31'].
#     RT13V34 has parents ['RT13V19', 'RT13V39'].
#     RT13V21 has parents ['RT13V31', 'RT13V39'].
#     RT13V48 has parents ['RT13V19', 'RT13V31'].
#     RT13V51 has parents ['RT13V48', 'RT13V19'].
#     RT13V15 has parents ['RT13V48', 'RT13V31'].
#     RT13V42 has parents ['RT13V15', 'RT13V29'].
#     RT13V24 has parents ['RT13V51', 'RT13V27'].
#     RT13V28 has parents ['RT13V15', 'RT13V33'].
#     RT13V49 has parents ['RT13V24', 'RT13V33'].
#     RT13V4  has parents ['RT13V24', 'RT13V19'].
#     RT13V7  has parents ['RT13V4', 'RT13V28'].
#     RT13V3  has parents ['RT13V34', 'RT13V27'].
#     RT13V43 has parents ['RT13V49', 'RT13V34'].
#     RT13V37 has parents ['RT13V24', 'RT13V48'].
#     RT13V45 has parents ['RT13V48', 'RT13V21'].
#     RT13V52 has parents ['RT13V37', 'RT13V21'].
#     RT13V32 has parents ['RT13V4', 'RT13V42'].
#     RT13V14 has parents ['RT13V28', 'RT13V24'].
#     RT13V30 has parents ['RT13V3', 'RT13V7'].
#     RT13V9  has parents ['RT13V7', 'RT13V34'].
#     RT13V22 has parents ['RT13V7', 'RT13V51'].
#     RT13V10 has parents ['RT13V24', 'RT13V48'].
#     RT13V46 has parents ['RT13V45', 'RT13V34'].
#     RT13V16 has parents ['RT13V14', 'RT13V42'].
#     RT13V13 has parents ['RT13V22', 'RT13V27'].
#     RT13V11 has parents ['RT13V14', 'RT13V3'].
#     RT13V36 has parents ['RT13V32', 'RT13V42'].
#     RT13V18 has parents ['RT13V30', 'RT13V31'].
#     RT13V25 has parents ['RT13V14', 'RT13V31'].
#     RT13V8  has parents ['RT13V25', 'RT13V33'].
#     RT13V40 has parents ['RT13V8', 'RT13V31'].
#     RT13V12 has parents ['RT13V13', 'RT13V28'].
# Comparison for epsilon 0.1 and degree 2
# Data generated for epsilon 0.2 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V30
# Adding attribute RT13V37
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V25
# Adding attribute RT13V46
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V29
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V49
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V28
# Adding attribute RT13V7
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.2 and degree 2
# Constructed Bayesian network:
#     RT13V30 has parents ['RT13V33'].
#     RT13V37 has parents ['RT13V30', 'RT13V33'].
#     RT13V31 has parents ['RT13V37', 'RT13V33'].
#     RT13V27 has parents ['RT13V37', 'RT13V33'].
#     RT13V19 has parents ['RT13V31', 'RT13V33'].
#     RT13V34 has parents ['RT13V31', 'RT13V30'].
#     RT13V21 has parents ['RT13V30', 'RT13V33'].
#     RT13V48 has parents ['RT13V27', 'RT13V37'].
#     RT13V51 has parents ['RT13V34', 'RT13V19'].
#     RT13V15 has parents ['RT13V27', 'RT13V30'].
#     RT13V42 has parents ['RT13V48', 'RT13V33'].
#     RT13V24 has parents ['RT13V27', 'RT13V31'].
#     RT13V25 has parents ['RT13V42', 'RT13V15'].
#     RT13V46 has parents ['RT13V25', 'RT13V42'].
#     RT13V4  has parents ['RT13V46', 'RT13V31'].
#     RT13V8  has parents ['RT13V15', 'RT13V33'].
#     RT13V3  has parents ['RT13V34', 'RT13V27'].
#     RT13V43 has parents ['RT13V21', 'RT13V19'].
#     RT13V39 has parents ['RT13V51', 'RT13V21'].
#     RT13V45 has parents ['RT13V48', 'RT13V34'].
#     RT13V52 has parents ['RT13V46', 'RT13V21'].
#     RT13V32 has parents ['RT13V24', 'RT13V42'].
#     RT13V14 has parents ['RT13V42', 'RT13V48'].
#     RT13V29 has parents ['RT13V52', 'RT13V4'].
#     RT13V9  has parents ['RT13V42', 'RT13V48'].
#     RT13V22 has parents ['RT13V43', 'RT13V48'].
#     RT13V10 has parents ['RT13V24', 'RT13V15'].
#     RT13V49 has parents ['RT13V21', 'RT13V34'].
#     RT13V16 has parents ['RT13V3', 'RT13V24'].
#     RT13V13 has parents ['RT13V24', 'RT13V34'].
#     RT13V11 has parents ['RT13V13', 'RT13V52'].
#     RT13V36 has parents ['RT13V9', 'RT13V42'].
#     RT13V18 has parents ['RT13V24', 'RT13V27'].
#     RT13V28 has parents ['RT13V9', 'RT13V31'].
#     RT13V7  has parents ['RT13V37', 'RT13V30'].
#     RT13V40 has parents ['RT13V39', 'RT13V31'].
#     RT13V12 has parents ['RT13V11', 'RT13V25'].
# Comparison for epsilon 0.2 and degree 2
# Data generated for epsilon 0.4 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V34
# Adding attribute RT13V42
# Adding attribute RT13V36
# Adding attribute RT13V29
# Adding attribute RT13V21
# Adding attribute RT13V37
# Adding attribute RT13V19
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V40
# Adding attribute RT13V24
# Adding attribute RT13V27
# Adding attribute RT13V46
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V30
# Adding attribute RT13V14
# Adding attribute RT13V31
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V49
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V28
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V7
# Adding attribute RT13V32
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.4 and degree 2
# Constructed Bayesian network:
#     RT13V34 has parents ['RT13V33'].
#     RT13V42 has parents ['RT13V34', 'RT13V33'].
#     RT13V36 has parents ['RT13V34', 'RT13V33'].
#     RT13V29 has parents ['RT13V42', 'RT13V34'].
#     RT13V21 has parents ['RT13V29', 'RT13V36'].
#     RT13V37 has parents ['RT13V42', 'RT13V34'].
#     RT13V19 has parents ['RT13V37', 'RT13V29'].
#     RT13V48 has parents ['RT13V19', 'RT13V21'].
#     RT13V51 has parents ['RT13V37', 'RT13V21'].
#     RT13V15 has parents ['RT13V21', 'RT13V36'].
#     RT13V40 has parents ['RT13V36', 'RT13V42'].
#     RT13V24 has parents ['RT13V51', 'RT13V29'].
#     RT13V27 has parents ['RT13V51', 'RT13V33'].
#     RT13V46 has parents ['RT13V24', 'RT13V48'].
#     RT13V4  has parents ['RT13V46', 'RT13V15'].
#     RT13V8  has parents ['RT13V48', 'RT13V42'].
#     RT13V3  has parents ['RT13V37', 'RT13V21'].
#     RT13V43 has parents ['RT13V8', 'RT13V29'].
#     RT13V39 has parents ['RT13V21', 'RT13V33'].
#     RT13V45 has parents ['RT13V40', 'RT13V29'].
#     RT13V52 has parents ['RT13V45', 'RT13V37'].
#     RT13V30 has parents ['RT13V52', 'RT13V15'].
#     RT13V14 has parents ['RT13V15', 'RT13V21'].
#     RT13V31 has parents ['RT13V30', 'RT13V33'].
#     RT13V9  has parents ['RT13V39', 'RT13V37'].
#     RT13V22 has parents ['RT13V8', 'RT13V29'].
#     RT13V10 has parents ['RT13V39', 'RT13V15'].
#     RT13V49 has parents ['RT13V31', 'RT13V29'].
#     RT13V16 has parents ['RT13V39', 'RT13V15'].
#     RT13V13 has parents ['RT13V27', 'RT13V48'].
#     RT13V11 has parents ['RT13V13', 'RT13V49'].
#     RT13V28 has parents ['RT13V11', 'RT13V52'].
#     RT13V18 has parents ['RT13V31', 'RT13V37'].
#     RT13V25 has parents ['RT13V51', 'RT13V48'].
#     RT13V7  has parents ['RT13V51', 'RT13V34'].
#     RT13V32 has parents ['RT13V8', 'RT13V37'].
#     RT13V12 has parents ['RT13V11', 'RT13V27'].
# Comparison for epsilon 0.4 and degree 2
# Data generated for epsilon 0.8 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V36
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V13
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V8
# Adding attribute RT13V31
# Adding attribute RT13V10
# Adding attribute RT13V15
# Adding attribute RT13V43
# Adding attribute RT13V4
# Adding attribute RT13V9
# Adding attribute RT13V3
# Adding attribute RT13V42
# Adding attribute RT13V37
# Adding attribute RT13V46
# Adding attribute RT13V52
# Adding attribute RT13V29
# Adding attribute RT13V21
# Adding attribute RT13V28
# Adding attribute RT13V11
# Adding attribute RT13V24
# Adding attribute RT13V12
# Adding attribute RT13V49
# Adding attribute RT13V22
# Adding attribute RT13V18
# Adding attribute RT13V16
# Adding attribute RT13V34
# Adding attribute RT13V25
# Adding attribute RT13V27
# Adding attribute RT13V7
# Adding attribute RT13V40
# Adding attribute RT13V19
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.8 and degree 2
# Constructed Bayesian network:
#     RT13V39 has parents ['RT13V33'].
#     RT13V45 has parents ['RT13V39', 'RT13V33'].
#     RT13V36 has parents ['RT13V45', 'RT13V39'].
#     RT13V32 has parents ['RT13V45', 'RT13V39'].
#     RT13V14 has parents ['RT13V32', 'RT13V45'].
#     RT13V30 has parents ['RT13V14', 'RT13V39'].
#     RT13V13 has parents ['RT13V36', 'RT13V33'].
#     RT13V48 has parents ['RT13V14', 'RT13V45'].
#     RT13V51 has parents ['RT13V32', 'RT13V36'].
#     RT13V8  has parents ['RT13V48', 'RT13V30'].
#     RT13V31 has parents ['RT13V8', 'RT13V30'].
#     RT13V10 has parents ['RT13V31', 'RT13V48'].
#     RT13V15 has parents ['RT13V10', 'RT13V13'].
#     RT13V43 has parents ['RT13V36', 'RT13V33'].
#     RT13V4  has parents ['RT13V14', 'RT13V39'].
#     RT13V9  has parents ['RT13V30', 'RT13V33'].
#     RT13V3  has parents ['RT13V4', 'RT13V36'].
#     RT13V42 has parents ['RT13V15', 'RT13V14'].
#     RT13V37 has parents ['RT13V32', 'RT13V33'].
#     RT13V46 has parents ['RT13V30', 'RT13V45'].
#     RT13V52 has parents ['RT13V48', 'RT13V13'].
#     RT13V29 has parents ['RT13V14', 'RT13V45'].
#     RT13V21 has parents ['RT13V15', 'RT13V32'].
#     RT13V28 has parents ['RT13V9', 'RT13V36'].
#     RT13V11 has parents ['RT13V3', 'RT13V48'].
#     RT13V24 has parents ['RT13V21', 'RT13V43'].
#     RT13V12 has parents ['RT13V3', 'RT13V13'].
#     RT13V49 has parents ['RT13V15', 'RT13V14'].
#     RT13V22 has parents ['RT13V48', 'RT13V45'].
#     RT13V18 has parents ['RT13V37', 'RT13V42'].
#     RT13V16 has parents ['RT13V52', 'RT13V42'].
#     RT13V34 has parents ['RT13V4', 'RT13V10'].
#     RT13V25 has parents ['RT13V37', 'RT13V32'].
#     RT13V27 has parents ['RT13V29', 'RT13V32'].
#     RT13V7  has parents ['RT13V25', 'RT13V33'].
#     RT13V40 has parents ['RT13V15', 'RT13V32'].
#     RT13V19 has parents ['RT13V16', 'RT13V15'].
# Comparison for epsilon 0.8 and degree 2
# Data generated for epsilon 1.6 and degree 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V42
# Adding attribute RT13V46
# Adding attribute RT13V45
# Adding attribute RT13V39
# Adding attribute RT13V36
# Adding attribute RT13V48
# Adding attribute RT13V14
# Adding attribute RT13V32
# Adding attribute RT13V51
# Adding attribute RT13V4
# Adding attribute RT13V30
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V31
# Adding attribute RT13V8
# Adding attribute RT13V9
# Adding attribute RT13V3
# Adding attribute RT13V34
# Adding attribute RT13V28
# Adding attribute RT13V40
# Adding attribute RT13V52
# Adding attribute RT13V25
# Adding attribute RT13V16
# Adding attribute RT13V27
# Adding attribute RT13V10
# Adding attribute RT13V21
# Adding attribute RT13V12
# Adding attribute RT13V43
# Adding attribute RT13V19
# Adding attribute RT13V18
# Adding attribute RT13V15
# Adding attribute RT13V29
# Adding attribute RT13V24
# Adding attribute RT13V37
# Adding attribute RT13V7
# Adding attribute RT13V49
# Adding attribute RT13V22
# ========================== BN constructed ==========================
# Bayesian for epsilon 1.6 and degree 2
# Constructed Bayesian network:
#     RT13V42 has parents ['RT13V33'].
#     RT13V46 has parents ['RT13V42', 'RT13V33'].
#     RT13V45 has parents ['RT13V46', 'RT13V33'].
#     RT13V39 has parents ['RT13V45', 'RT13V33'].
#     RT13V36 has parents ['RT13V45', 'RT13V33'].
#     RT13V48 has parents ['RT13V45', 'RT13V46'].
#     RT13V14 has parents ['RT13V36', 'RT13V46'].
#     RT13V32 has parents ['RT13V14', 'RT13V48'].
#     RT13V51 has parents ['RT13V45', 'RT13V46'].
#     RT13V4  has parents ['RT13V14', 'RT13V36'].
#     RT13V30 has parents ['RT13V14', 'RT13V45'].
#     RT13V13 has parents ['RT13V14', 'RT13V39'].
#     RT13V11 has parents ['RT13V48', 'RT13V46'].
#     RT13V31 has parents ['RT13V13', 'RT13V4'].
#     RT13V8  has parents ['RT13V14', 'RT13V42'].
#     RT13V9  has parents ['RT13V48', 'RT13V33'].
#     RT13V3  has parents ['RT13V14', 'RT13V45'].
#     RT13V34 has parents ['RT13V11', 'RT13V14'].
#     RT13V28 has parents ['RT13V34', 'RT13V45'].
#     RT13V40 has parents ['RT13V28', 'RT13V42'].
#     RT13V52 has parents ['RT13V14', 'RT13V36'].
#     RT13V25 has parents ['RT13V52', 'RT13V34'].
#     RT13V16 has parents ['RT13V3', 'RT13V42'].
#     RT13V27 has parents ['RT13V9', 'RT13V33'].
#     RT13V10 has parents ['RT13V11', 'RT13V48'].
#     RT13V21 has parents ['RT13V10', 'RT13V3'].
#     RT13V12 has parents ['RT13V28', 'RT13V51'].
#     RT13V43 has parents ['RT13V52', 'RT13V3'].
#     RT13V19 has parents ['RT13V12', 'RT13V36'].
#     RT13V18 has parents ['RT13V8', 'RT13V30'].
#     RT13V15 has parents ['RT13V10', 'RT13V31'].
#     RT13V29 has parents ['RT13V31', 'RT13V11'].
#     RT13V24 has parents ['RT13V21', 'RT13V4'].
#     RT13V37 has parents ['RT13V18', 'RT13V45'].
#     RT13V7  has parents ['RT13V15', 'RT13V33'].
#     RT13V49 has parents ['RT13V30', 'RT13V39'].
#     RT13V22 has parents ['RT13V7', 'RT13V11'].
# Comparison for epsilon 1.6 and degree 2

# %%
#Run Datasynth on multiple different values of epsilon and degree of Bayesian Network equal to 3
epsilon_vals = [0.05, 0.1, 0.2, 0.4, 0.8, 1.6]
for epsilon in epsilon_vals:
    describers = []
    describer = runDataSynth(3, epsilon, num_tuples_to_generate, threshold_value, null_values, description_file, synthetic_data)
    describers.append(describer)
# Out:
# Data generated for epsilon 0.05 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V7
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V8
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.05 and degree 3
# Constructed Bayesian network:
#     RT13V29 has parents ['RT13V33'].
#     RT13V39 has parents ['RT13V29', 'RT13V33'].
#     RT13V31 has parents ['RT13V29', 'RT13V39', 'RT13V33'].
#     RT13V27 has parents ['RT13V39', 'RT13V31', 'RT13V33'].
#     RT13V19 has parents ['RT13V31', 'RT13V27', 'RT13V39'].
#     RT13V34 has parents ['RT13V31', 'RT13V19', 'RT13V29'].
#     RT13V21 has parents ['RT13V31', 'RT13V27', 'RT13V29'].
#     RT13V48 has parents ['RT13V27', 'RT13V19', 'RT13V39'].
#     RT13V51 has parents ['RT13V34', 'RT13V21', 'RT13V27'].
#     RT13V15 has parents ['RT13V19', 'RT13V48', 'RT13V39'].
#     RT13V42 has parents ['RT13V31', 'RT13V21', 'RT13V29'].
#     RT13V24 has parents ['RT13V19', 'RT13V15', 'RT13V31'].
#     RT13V28 has parents ['RT13V19', 'RT13V21', 'RT13V33'].
#     RT13V49 has parents ['RT13V21', 'RT13V51', 'RT13V33'].
#     RT13V4  has parents ['RT13V42', 'RT13V49', 'RT13V31'].
#     RT13V7  has parents ['RT13V28', 'RT13V4', 'RT13V51'].
#     RT13V3  has parents ['RT13V15', 'RT13V42', 'RT13V39'].
#     RT13V43 has parents ['RT13V42', 'RT13V28', 'RT13V27'].
#     RT13V37 has parents ['RT13V48', 'RT13V43', 'RT13V34'].
#     RT13V45 has parents ['RT13V34', 'RT13V43', 'RT13V19'].
#     RT13V52 has parents ['RT13V42', 'RT13V28', 'RT13V19'].
#     RT13V32 has parents ['RT13V15', 'RT13V4', 'RT13V48'].
#     RT13V14 has parents ['RT13V7', 'RT13V43', 'RT13V51'].
#     RT13V30 has parents ['RT13V7', 'RT13V52', 'RT13V24'].
#     RT13V9  has parents ['RT13V49', 'RT13V30', 'RT13V27'].
#     RT13V22 has parents ['RT13V14', 'RT13V30', 'RT13V34'].
#     RT13V10 has parents ['RT13V52', 'RT13V22', 'RT13V19'].
#     RT13V46 has parents ['RT13V49', 'RT13V4', 'RT13V27'].
#     RT13V16 has parents ['RT13V4', 'RT13V45', 'RT13V48'].
#     RT13V13 has parents ['RT13V48', 'RT13V30', 'RT13V31'].
#     RT13V11 has parents ['RT13V7', 'RT13V52', 'RT13V28'].
#     RT13V36 has parents ['RT13V7', 'RT13V30', 'RT13V48'].
#     RT13V18 has parents ['RT13V3', 'RT13V9', 'RT13V39'].
#     RT13V25 has parents ['RT13V3', 'RT13V11', 'RT13V39'].
#     RT13V8  has parents ['RT13V49', 'RT13V11', 'RT13V33'].
#     RT13V40 has parents ['RT13V45', 'RT13V30', 'RT13V39'].
#     RT13V12 has parents ['RT13V30', 'RT13V9', 'RT13V51'].
# Comparison for epsilon 0.05 and degree 3
# Data generated for epsilon 0.1 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V29
# Adding attribute RT13V39
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V21
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V28
# Adding attribute RT13V49
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V37
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V30
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V7
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.1 and degree 3
# Constructed Bayesian network:
#     RT13V29 has parents ['RT13V33'].
#     RT13V39 has parents ['RT13V29', 'RT13V33'].
#     RT13V31 has parents ['RT13V29', 'RT13V39', 'RT13V33'].
#     RT13V27 has parents ['RT13V39', 'RT13V31', 'RT13V33'].
#     RT13V19 has parents ['RT13V31', 'RT13V27', 'RT13V29'].
#     RT13V34 has parents ['RT13V27', 'RT13V19', 'RT13V29'].
#     RT13V21 has parents ['RT13V39', 'RT13V34', 'RT13V29'].
#     RT13V48 has parents ['RT13V31', 'RT13V21', 'RT13V39'].
#     RT13V51 has parents ['RT13V19', 'RT13V34', 'RT13V27'].
#     RT13V15 has parents ['RT13V31', 'RT13V34', 'RT13V39'].
#     RT13V42 has parents ['RT13V39', 'RT13V48', 'RT13V29'].
#     RT13V24 has parents ['RT13V21', 'RT13V42', 'RT13V39'].
#     RT13V28 has parents ['RT13V39', 'RT13V24', 'RT13V33'].
#     RT13V49 has parents ['RT13V27', 'RT13V48', 'RT13V33'].
#     RT13V4  has parents ['RT13V42', 'RT13V24', 'RT13V31'].
#     RT13V8  has parents ['RT13V29', 'RT13V51', 'RT13V33'].
#     RT13V3  has parents ['RT13V42', 'RT13V24', 'RT13V39'].
#     RT13V43 has parents ['RT13V21', 'RT13V4', 'RT13V27'].
#     RT13V37 has parents ['RT13V48', 'RT13V49', 'RT13V19'].
#     RT13V45 has parents ['RT13V51', 'RT13V49', 'RT13V27'].
#     RT13V52 has parents ['RT13V51', 'RT13V4', 'RT13V19'].
#     RT13V32 has parents ['RT13V51', 'RT13V24', 'RT13V48'].
#     RT13V14 has parents ['RT13V28', 'RT13V32', 'RT13V48'].
#     RT13V30 has parents ['RT13V4', 'RT13V32', 'RT13V24'].
#     RT13V9  has parents ['RT13V15', 'RT13V43', 'RT13V19'].
#     RT13V22 has parents ['RT13V4', 'RT13V37', 'RT13V34'].
#     RT13V10 has parents ['RT13V37', 'RT13V9', 'RT13V34'].
#     RT13V46 has parents ['RT13V42', 'RT13V52', 'RT13V27'].
#     RT13V16 has parents ['RT13V37', 'RT13V46', 'RT13V48'].
#     RT13V13 has parents ['RT13V32', 'RT13V16', 'RT13V31'].
#     RT13V11 has parents ['RT13V52', 'RT13V16', 'RT13V4'].
#     RT13V36 has parents ['RT13V8', 'RT13V46', 'RT13V48'].
#     RT13V18 has parents ['RT13V9', 'RT13V22', 'RT13V39'].
#     RT13V25 has parents ['RT13V43', 'RT13V16', 'RT13V39'].
#     RT13V7  has parents ['RT13V4', 'RT13V32', 'RT13V33'].
#     RT13V40 has parents ['RT13V28', 'RT13V13', 'RT13V39'].
#     RT13V12 has parents ['RT13V9', 'RT13V22', 'RT13V51'].
# Comparison for epsilon 0.1 and degree 3
# Data generated for epsilon 0.2 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V30
# Adding attribute RT13V37
# Adding attribute RT13V31
# Adding attribute RT13V27
# Adding attribute RT13V19
# Adding attribute RT13V34
# Adding attribute RT13V18
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V42
# Adding attribute RT13V24
# Adding attribute RT13V25
# Adding attribute RT13V46
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V43
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V32
# Adding attribute RT13V14
# Adding attribute RT13V29
# Adding attribute RT13V9
# Adding attribute RT13V22
# Adding attribute RT13V10
# Adding attribute RT13V49
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V11
# Adding attribute RT13V36
# Adding attribute RT13V21
# Adding attribute RT13V28
# Adding attribute RT13V7
# Adding attribute RT13V40
# Adding attribute RT13V12
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.2 and degree 3
# Constructed Bayesian network:
#     RT13V30 has parents ['RT13V33'].
#     RT13V37 has parents ['RT13V30', 'RT13V33'].
#     RT13V31 has parents ['RT13V30', 'RT13V37', 'RT13V33'].
#     RT13V27 has parents ['RT13V30', 'RT13V31', 'RT13V33'].
#     RT13V19 has parents ['RT13V30', 'RT13V37', 'RT13V33'].
#     RT13V34 has parents ['RT13V31', 'RT13V19', 'RT13V33'].
#     RT13V18 has parents ['RT13V27', 'RT13V34', 'RT13V37'].
#     RT13V48 has parents ['RT13V37', 'RT13V34', 'RT13V30'].
#     RT13V51 has parents ['RT13V19', 'RT13V34', 'RT13V31'].
#     RT13V15 has parents ['RT13V30', 'RT13V19', 'RT13V33'].
#     RT13V42 has parents ['RT13V37', 'RT13V34', 'RT13V33'].
#     RT13V24 has parents ['RT13V27', 'RT13V48', 'RT13V30'].
#     RT13V25 has parents ['RT13V51', 'RT13V42', 'RT13V19'].
#     RT13V46 has parents ['RT13V48', 'RT13V51', 'RT13V18'].
#     RT13V4  has parents ['RT13V27', 'RT13V48', 'RT13V31'].
#     RT13V8  has parents ['RT13V19', 'RT13V4', 'RT13V33'].
#     RT13V3  has parents ['RT13V42', 'RT13V8', 'RT13V37'].
#     RT13V43 has parents ['RT13V27', 'RT13V48', 'RT13V31'].
#     RT13V39 has parents ['RT13V18', 'RT13V25', 'RT13V27'].
#     RT13V45 has parents ['RT13V15', 'RT13V39', 'RT13V31'].
#     RT13V52 has parents ['RT13V34', 'RT13V3', 'RT13V19'].
#     RT13V32 has parents ['RT13V24', 'RT13V45', 'RT13V18'].
#     RT13V14 has parents ['RT13V34', 'RT13V39', 'RT13V27'].
#     RT13V29 has parents ['RT13V46', 'RT13V32', 'RT13V42'].
#     RT13V9  has parents ['RT13V42', 'RT13V45', 'RT13V19'].
#     RT13V22 has parents ['RT13V51', 'RT13V52', 'RT13V19'].
#     RT13V10 has parents ['RT13V51', 'RT13V32', 'RT13V18'].
#     RT13V49 has parents ['RT13V43', 'RT13V14', 'RT13V31'].
#     RT13V16 has parents ['RT13V51', 'RT13V49', 'RT13V48'].
#     RT13V13 has parents ['RT13V34', 'RT13V51', 'RT13V27'].
#     RT13V11 has parents ['RT13V14', 'RT13V9', 'RT13V3'].
#     RT13V36 has parents ['RT13V4', 'RT13V39', 'RT13V48'].
#     RT13V21 has parents ['RT13V24', 'RT13V4', 'RT13V37'].
#     RT13V28 has parents ['RT13V27', 'RT13V21', 'RT13V37'].
#     RT13V7  has parents ['RT13V4', 'RT13V11', 'RT13V33'].
#     RT13V40 has parents ['RT13V31', 'RT13V36', 'RT13V37'].
#     RT13V12 has parents ['RT13V49', 'RT13V21', 'RT13V51'].
# Comparison for epsilon 0.2 and degree 3
# Data generated for epsilon 0.4 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V34
# Adding attribute RT13V42
# Adding attribute RT13V36
# Adding attribute RT13V29
# Adding attribute RT13V22
# Adding attribute RT13V39
# Adding attribute RT13V21
# Adding attribute RT13V49
# Adding attribute RT13V51
# Adding attribute RT13V15
# Adding attribute RT13V43
# Adding attribute RT13V24
# Adding attribute RT13V27
# Adding attribute RT13V48
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V40
# Adding attribute RT13V32
# Adding attribute RT13V45
# Adding attribute RT13V52
# Adding attribute RT13V30
# Adding attribute RT13V14
# Adding attribute RT13V28
# Adding attribute RT13V9
# Adding attribute RT13V19
# Adding attribute RT13V10
# Adding attribute RT13V46
# Adding attribute RT13V16
# Adding attribute RT13V13
# Adding attribute RT13V12
# Adding attribute RT13V31
# Adding attribute RT13V18
# Adding attribute RT13V25
# Adding attribute RT13V7
# Adding attribute RT13V37
# Adding attribute RT13V11
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.4 and degree 3
# Constructed Bayesian network:
#     RT13V34 has parents ['RT13V33'].
#     RT13V42 has parents ['RT13V34', 'RT13V33'].
#     RT13V36 has parents ['RT13V34', 'RT13V42', 'RT13V33'].
#     RT13V29 has parents ['RT13V42', 'RT13V36', 'RT13V33'].
#     RT13V22 has parents ['RT13V34', 'RT13V42', 'RT13V33'].
#     RT13V39 has parents ['RT13V34', 'RT13V36', 'RT13V33'].
#     RT13V21 has parents ['RT13V42', 'RT13V29', 'RT13V33'].
#     RT13V49 has parents ['RT13V42', 'RT13V21', 'RT13V33'].
#     RT13V51 has parents ['RT13V22', 'RT13V49', 'RT13V36'].
#     RT13V15 has parents ['RT13V49', 'RT13V51', 'RT13V34'].
#     RT13V43 has parents ['RT13V29', 'RT13V21', 'RT13V42'].
#     RT13V24 has parents ['RT13V21', 'RT13V49', 'RT13V42'].
#     RT13V27 has parents ['RT13V42', 'RT13V49', 'RT13V33'].
#     RT13V48 has parents ['RT13V36', 'RT13V43', 'RT13V42'].
#     RT13V4  has parents ['RT13V15', 'RT13V27', 'RT13V51'].
#     RT13V8  has parents ['RT13V51', 'RT13V15', 'RT13V34'].
#     RT13V3  has parents ['RT13V21', 'RT13V4', 'RT13V36'].
#     RT13V40 has parents ['RT13V15', 'RT13V43', 'RT13V29'].
#     RT13V32 has parents ['RT13V51', 'RT13V8', 'RT13V22'].
#     RT13V45 has parents ['RT13V27', 'RT13V40', 'RT13V42'].
#     RT13V52 has parents ['RT13V49', 'RT13V24', 'RT13V29'].
#     RT13V30 has parents ['RT13V49', 'RT13V24', 'RT13V39'].
#     RT13V14 has parents ['RT13V39', 'RT13V32', 'RT13V34'].
#     RT13V28 has parents ['RT13V43', 'RT13V4', 'RT13V51'].
#     RT13V9  has parents ['RT13V15', 'RT13V14', 'RT13V29'].
#     RT13V19 has parents ['RT13V39', 'RT13V48', 'RT13V42'].
#     RT13V10 has parents ['RT13V40', 'RT13V14', 'RT13V21'].
#     RT13V46 has parents ['RT13V21', 'RT13V43', 'RT13V36'].
#     RT13V16 has parents ['RT13V4', 'RT13V45', 'RT13V39'].
#     RT13V13 has parents ['RT13V8', 'RT13V40', 'RT13V22'].
#     RT13V12 has parents ['RT13V39', 'RT13V45', 'RT13V33'].
#     RT13V31 has parents ['RT13V52', 'RT13V30', 'RT13V49'].
#     RT13V18 has parents ['RT13V51', 'RT13V32', 'RT13V42'].
#     RT13V25 has parents ['RT13V22', 'RT13V51', 'RT13V34'].
#     RT13V7  has parents ['RT13V8', 'RT13V12', 'RT13V33'].
#     RT13V37 has parents ['RT13V21', 'RT13V19', 'RT13V34'].
#     RT13V11 has parents ['RT13V43', 'RT13V27', 'RT13V15'].
# Comparison for epsilon 0.4 and degree 3
# Data generated for epsilon 0.8 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V39
# Adding attribute RT13V45
# Adding attribute RT13V36
# Adding attribute RT13V32
# Adding attribute RT13V13
# Adding attribute RT13V30
# Adding attribute RT13V12
# Adding attribute RT13V48
# Adding attribute RT13V51
# Adding attribute RT13V9
# Adding attribute RT13V31
# Adding attribute RT13V14
# Adding attribute RT13V11
# Adding attribute RT13V42
# Adding attribute RT13V4
# Adding attribute RT13V8
# Adding attribute RT13V3
# Adding attribute RT13V40
# Adding attribute RT13V34
# Adding attribute RT13V46
# Adding attribute RT13V52
# Adding attribute RT13V29
# Adding attribute RT13V19
# Adding attribute RT13V28
# Adding attribute RT13V10
# Adding attribute RT13V24
# Adding attribute RT13V15
# Adding attribute RT13V49
# Adding attribute RT13V21
# Adding attribute RT13V18
# Adding attribute RT13V16
# Adding attribute RT13V37
# Adding attribute RT13V25
# Adding attribute RT13V27
# Adding attribute RT13V7
# Adding attribute RT13V43
# Adding attribute RT13V22
# ========================== BN constructed ==========================
# Bayesian for epsilon 0.8 and degree 3
# Constructed Bayesian network:
#     RT13V39 has parents ['RT13V33'].
#     RT13V45 has parents ['RT13V39', 'RT13V33'].
#     RT13V36 has parents ['RT13V39', 'RT13V45', 'RT13V33'].
#     RT13V32 has parents ['RT13V45', 'RT13V36', 'RT13V33'].
#     RT13V13 has parents ['RT13V36', 'RT13V32', 'RT13V45'].
#     RT13V30 has parents ['RT13V39', 'RT13V32', 'RT13V33'].
#     RT13V12 has parents ['RT13V39', 'RT13V32', 'RT13V33'].
#     RT13V48 has parents ['RT13V36', 'RT13V32', 'RT13V39'].
#     RT13V51 has parents ['RT13V36', 'RT13V13', 'RT13V45'].
#     RT13V9  has parents ['RT13V12', 'RT13V51', 'RT13V39'].
#     RT13V31 has parents ['RT13V30', 'RT13V48', 'RT13V36'].
#     RT13V14 has parents ['RT13V13', 'RT13V48', 'RT13V39'].
#     RT13V11 has parents ['RT13V51', 'RT13V9', 'RT13V12'].
#     RT13V42 has parents ['RT13V51', 'RT13V14', 'RT13V48'].
#     RT13V4  has parents ['RT13V30', 'RT13V48', 'RT13V33'].
#     RT13V8  has parents ['RT13V45', 'RT13V32', 'RT13V33'].
#     RT13V3  has parents ['RT13V32', 'RT13V13', 'RT13V45'].
#     RT13V40 has parents ['RT13V4', 'RT13V3', 'RT13V12'].
#     RT13V34 has parents ['RT13V9', 'RT13V11', 'RT13V48'].
#     RT13V46 has parents ['RT13V42', 'RT13V40', 'RT13V33'].
#     RT13V52 has parents ['RT13V11', 'RT13V42', 'RT13V32'].
#     RT13V29 has parents ['RT13V39', 'RT13V31', 'RT13V33'].
#     RT13V19 has parents ['RT13V31', 'RT13V29', 'RT13V48'].
#     RT13V28 has parents ['RT13V30', 'RT13V12', 'RT13V33'].
#     RT13V10 has parents ['RT13V48', 'RT13V8', 'RT13V36'].
#     RT13V24 has parents ['RT13V9', 'RT13V14', 'RT13V51'].
#     RT13V15 has parents ['RT13V9', 'RT13V24', 'RT13V13'].
#     RT13V49 has parents ['RT13V31', 'RT13V14', 'RT13V45'].
#     RT13V21 has parents ['RT13V34', 'RT13V15', 'RT13V9'].
#     RT13V18 has parents ['RT13V42', 'RT13V8', 'RT13V31'].
#     RT13V16 has parents ['RT13V15', 'RT13V18', 'RT13V31'].
#     RT13V37 has parents ['RT13V14', 'RT13V11', 'RT13V48'].
#     RT13V25 has parents ['RT13V52', 'RT13V18', 'RT13V45'].
#     RT13V27 has parents ['RT13V19', 'RT13V37', 'RT13V45'].
#     RT13V7  has parents ['RT13V11', 'RT13V10', 'RT13V33'].
#     RT13V43 has parents ['RT13V32', 'RT13V9', 'RT13V36'].
#     RT13V22 has parents ['RT13V28', 'RT13V25', 'RT13V51'].
# Comparison for epsilon 0.8 and degree 3
# Data generated for epsilon 1.6 and degree 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT RT13V33
# Adding attribute RT13V42
# Adding attribute RT13V46
# Adding attribute RT13V45
# Adding attribute RT13V39
# Adding attribute RT13V36
# Adding attribute RT13V48
# Adding attribute RT13V14
# Adding attribute RT13V31
# Adding attribute RT13V51
# Adding attribute RT13V4
# Adding attribute RT13V30
# Adding attribute RT13V13
# Adding attribute RT13V10
# Adding attribute RT13V32
# Adding attribute RT13V8
# Adding attribute RT13V9
# Adding attribute RT13V3
# Adding attribute RT13V29
# Adding attribute RT13V27
# Adding attribute RT13V37
# Adding attribute RT13V52
# Adding attribute RT13V24
# Adding attribute RT13V18
# Adding attribute RT13V22
# Adding attribute RT13V11
# Adding attribute RT13V21
# Adding attribute RT13V12
# Adding attribute RT13V43
# Adding attribute RT13V15
# Adding attribute RT13V25
# Adding attribute RT13V16
# Adding attribute RT13V40
# Adding attribute RT13V28
# Adding attribute RT13V34
# Adding attribute RT13V7
# Adding attribute RT13V49
# Adding attribute RT13V19
# ========================== BN constructed ==========================
# Bayesian for epsilon 1.6 and degree 3
# Constructed Bayesian network:
#     RT13V42 has parents ['RT13V33'].
#     RT13V46 has parents ['RT13V42', 'RT13V33'].
#     RT13V45 has parents ['RT13V42', 'RT13V46', 'RT13V33'].
#     RT13V39 has parents ['RT13V42', 'RT13V45', 'RT13V33'].
#     RT13V36 has parents ['RT13V42', 'RT13V39', 'RT13V33'].
#     RT13V48 has parents ['RT13V45', 'RT13V39', 'RT13V42'].
#     RT13V14 has parents ['RT13V39', 'RT13V48', 'RT13V42'].
#     RT13V31 has parents ['RT13V48', 'RT13V14', 'RT13V39'].
#     RT13V51 has parents ['RT13V48', 'RT13V14', 'RT13V33'].
#     RT13V4  has parents ['RT13V14', 'RT13V51', 'RT13V46'].
#     RT13V30 has parents ['RT13V36', 'RT13V4', 'RT13V42'].
#     RT13V13 has parents ['RT13V36', 'RT13V14', 'RT13V46'].
#     RT13V10 has parents ['RT13V30', 'RT13V13', 'RT13V36'].
#     RT13V32 has parents ['RT13V30', 'RT13V10', 'RT13V48'].
#     RT13V8  has parents ['RT13V14', 'RT13V32', 'RT13V33'].
#     RT13V9  has parents ['RT13V45', 'RT13V10', 'RT13V33'].
#     RT13V3  has parents ['RT13V32', 'RT13V8', 'RT13V42'].
#     RT13V29 has parents ['RT13V4', 'RT13V10', 'RT13V14'].
#     RT13V27 has parents ['RT13V14', 'RT13V3', 'RT13V33'].
#     RT13V37 has parents ['RT13V39', 'RT13V32', 'RT13V45'].
#     RT13V52 has parents ['RT13V14', 'RT13V4', 'RT13V46'].
#     RT13V24 has parents ['RT13V32', 'RT13V29', 'RT13V10'].
#     RT13V18 has parents ['RT13V13', 'RT13V10', 'RT13V42'].
#     RT13V22 has parents ['RT13V51', 'RT13V37', 'RT13V46'].
#     RT13V11 has parents ['RT13V51', 'RT13V10', 'RT13V31'].
#     RT13V21 has parents ['RT13V37', 'RT13V18', 'RT13V42'].
#     RT13V12 has parents ['RT13V3', 'RT13V24', 'RT13V45'].
#     RT13V43 has parents ['RT13V27', 'RT13V37', 'RT13V29'].
#     RT13V15 has parents ['RT13V24', 'RT13V11', 'RT13V29'].
#     RT13V25 has parents ['RT13V24', 'RT13V11', 'RT13V42'].
#     RT13V16 has parents ['RT13V52', 'RT13V12', 'RT13V51'].
#     RT13V40 has parents ['RT13V8', 'RT13V21', 'RT13V36'].
#     RT13V28 has parents ['RT13V52', 'RT13V22', 'RT13V42'].
#     RT13V34 has parents ['RT13V32', 'RT13V8', 'RT13V42'].
#     RT13V7  has parents ['RT13V13', 'RT13V34', 'RT13V33'].
#     RT13V49 has parents ['RT13V31', 'RT13V30', 'RT13V46'].
#     RT13V19 has parents ['RT13V11', 'RT13V16', 'RT13V51'].
# Comparison for epsilon 1.6 and degree 3

# %%
#Run Datasynth on multiple different values of epsilon and degree of Bayesian Network equal to 4(DID NOT RUN DUE TO RUNTIME)
epsilon_vals = [0.05, 0.1, 0.2, 0.4, 0.8, 1.6]
for epsilon in epsilon_vals:
    runDataSynth(4, epsilon, num_tuples_to_generate, threshold_value, null_values, description_file, synthetic_data)
